# %%
from auxilary_annalysis_mm import plot_featSpaceDist

# %%
plot_featSpaceDist(21, 31, 36, 46)

# %%
import numpy as np
for aa in np.arange(3600):
    print('arrayIndex: {}, row: {}, col: {}'.format(aa, int(aa/60 + 1), int(aa%60 + 1)))
# Out:
# arrayIndex: 0, row: 1, col: 1
# arrayIndex: 1, row: 1, col: 2
# arrayIndex: 2, row: 1, col: 3
# arrayIndex: 3, row: 1, col: 4
# arrayIndex: 4, row: 1, col: 5
# arrayIndex: 5, row: 1, col: 6
# arrayIndex: 6, row: 1, col: 7
# arrayIndex: 7, row: 1, col: 8
# arrayIndex: 8, row: 1, col: 9
# arrayIndex: 9, row: 1, col: 10
# arrayIndex: 10, row: 1, col: 11
# arrayIndex: 11, row: 1, col: 12
# arrayIndex: 12, row: 1, col: 13
# arrayIndex: 13, row: 1, col: 14
# arrayIndex: 14, row: 1, col: 15
# arrayIndex: 15, row: 1, col: 16
# arrayIndex: 16, row: 1, col: 17
# arrayIndex: 17, row: 1, col: 18
# arrayIndex: 18, row: 1, col: 19
# arrayIndex: 19, row: 1, col: 20
# arrayIndex: 20, row: 1, col: 21
# arrayIndex: 21, row: 1, col: 22
# arrayIndex: 22, row: 1, col: 23
# arrayIndex: 23, row: 1, col: 24
# arrayIndex: 24, row: 1, col: 25
# arrayIndex: 25, row: 1, col: 26
# arrayIndex: 26, row: 1, col: 27
# arrayIndex: 27, row: 1, col: 28
# arrayIndex: 28, row: 1, col: 29
# ...
